# %%
import csv
import numpy as np
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
path='C:\\Users\\Cristhian\\Desktop\\'
path2='C:\\Users\\Cristhian\\Documents\\TEETH-RECOGNITION-WITH-MACHINE-LEARNING\\Labels\\'
feature_file_name = 'featuresHSV.csv'
label_file_name='Labels.csv'

# %%
def convertRowToFloat(string):
    x = string.split(",")
    result=[]
    for r in x:
        result.append(float(r))
    return result

# %%
def createFeatureMatrix():
    results = []
    with open(path+feature_file_name) as csvfile:
        for row in csvfile:
            row_ = row[13:]
            results.append(convertRowToFloat(row_))
    return results

# %%
def createLabelsVector(string):
    x_ = string.strip("\n")
    x = x_.split(";")
    result=[]
    for r in x:
        result.append(r)    
    return result

# %%
def getDataLabels():
    result=[]
    print(path+label_file_name)
    with open(path+label_file_name) as csvfile:
        for row in csvfile:
            row_=row[9:]
            result.append(createLabelsVector(row_))
    return result

# %%
def SVM(i):
    parameter = [{
        "kernel":['rbf'],
        "gamma":[1e-4,1e-3,1e-2,0.1,0.2,0.5],
        "C":[10.0,100.0,1000.0,10000.0]
    }]
    X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=i,random_state=0)
    clf = GridSearchCV(svm.SVC(),param_grid=parameter,cv = 5)
    clf.fit(X_train, Y_train)
    porcentaje = i*100
    print("Se entrenó la SVM con ",porcentaje,"% para pruebas")
    return clf

# %%
def DT(i):
    depth = [] 
    for j in range(1,101):
        depth.append(int(j))
    depth.append(None)
    parameter = [{
        "criterion":['gini','entropy'],
        "splitter":["best","random"],
        "max_depth":depth,
        "min_samples_split":[2,3,4,5,6,7,8,9,10]
    }]
    X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=i,random_state=0)
    clf = GridSearchCV(DecisionTreeClassifier(),param_grid=parameter,cv = 5)
    clf.fit(X_train,Y_train)
    porcentaje = i*100
    print("Se entrenó Arboles de Decisión con ",porcentaje,"% para pruebas")
    return clf

# %%
def KNN(i):
    neighbors = [] 
    for j in range(1,101):
        neighbors.append(int(j))
    parameter = [{
        'n_neighbors':neighbors,
        'algorithm':['auto'],
        'weights':['uniform','distance'],
        'n_jobs':[-1]
    }]
    X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=i,random_state=0)
    clf = GridSearchCV(KNeighborsClassifier(),param_grid=parameter,cv = 5)
    clf.fit(X_train,Y_train)
    porcentaje = i*100
    print("Se entrenó K-Vecinos más cercanos con ",porcentaje,"% para pruebas")
    return clf

# %%
def predicClassifier(clf, test_data):
    return clf.predict(test_data)

# %%
def confusionMatrix(predict_classifier,test_label):
    return confusion_matrix(test_label,predict_classifier)

# %%
def letGetSomeMainOverHere():
    test_rate = [0.30,0.25,0.20]
    svm=[]
    knn=[]
    dt=[]
    for i in test_rate:
        svm.append(SVM(i))
        knn.append(KNN(i))
        dt.append(DT(i))
    return svm,knn,dt

# %%
X = createFeatureMatrix()
y = getDataLabels()
y = np.ravel(y,order='C')
# Out:
# C:\Users\Cristhian\Desktop\Labels.csv

# %%
svm_,knn_,dt_ = letGetSomeMainOverHere()
# Out:
# Se entrenó la SVM con  30.0 % para pruebas
# c:\users\cristhian\appdata\local\programs\python\python36\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Se entrenó K-Vecinos más cercanos con  30.0 % para pruebas
# c:\users\cristhian\appdata\local\programs\python\python36\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Se entrenó Arboles de Decisión con  30.0 % para pruebas
# Se entrenó la SVM con  25.0 % para pruebas
# c:\users\cristhian\appdata\local\programs\python\python36\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Se entrenó K-Vecinos más cercanos con  25.0 % para pruebas
# c:\users\cristhian\appdata\local\programs\python\python36\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Se entrenó Arboles de Decisión con  25.0 % para pruebas
# Se entrenó la SVM con  20.0 % para pruebas
# c:\users\cristhian\appdata\local\programs\python\python36\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Se entrenó K-Vecinos más cercanos con  20.0 % para pruebas
# Se entrenó Arboles de Decisión con  20.0 % para pruebas
# c:\users\cristhian\appdata\local\programs\python\python36\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
particion = ["Partición (70-20):","Partición (75-25):","Partición (80-20):"]

# %%
print("Características en el espacio LAB - uso de máquinas de soporte vectorial (SVM):")
for s in range(0,len(svm_)):
    print("\t" ,particion[s]," ", svm_[s].best_params_ , " " , svm_[s].best_score_)
# Out:
# Características en el espacio LAB - uso de máquinas de soporte vectorial (SVM):
# 	 Partición (70-20):   {'C': 10.0, 'gamma': 0.01, 'kernel': 'rbf'}   0.45147679324894513
# 	 Partición (75-25):   {'C': 10.0, 'gamma': 0.01, 'kernel': 'rbf'}   0.458005249343832
# 	 Partición (80-20):   {'C': 10.0, 'gamma': 0.01, 'kernel': 'rbf'}   0.45197044334975367

# %%
print("Características en el espacio LAB - uso de K - Vecinos más Cercanos (KNN):")
for s in range(0,len(knn_)):
    print("\t" ,particion[s]," ", knn_[s].best_params_ , " " , knn_[s].best_score_)
# Out:
# Características en el espacio LAB - uso de K - Vecinos más Cercanos (KNN):
# 	 Partición (70-20):   {'algorithm': 'auto', 'n_jobs': -1, 'n_neighbors': 82, 'weights': 'uniform'}   0.44163150492264414
# 	 Partición (75-25):   {'algorithm': 'auto', 'n_jobs': -1, 'n_neighbors': 83, 'weights': 'uniform'}   0.4409448818897638
# 	 Partición (80-20):   {'algorithm': 'auto', 'n_jobs': -1, 'n_neighbors': 89, 'weights': 'distance'}   0.4396551724137931

# %%
print("Características en el espacio LAB - uso de Árboles de decisión (DT):")
for s in range(0,len(dt_)):
    print("\t" ,particion[s]," ", dt_[s].best_params_ , " " , dt_[s].best_score_)
# Out:
# Características en el espacio LAB - uso de Árboles de decisión (DT):
# 	 Partición (70-20):   {'criterion': 'entropy', 'max_depth': 31, 'min_samples_split': 10, 'splitter': 'random'}   0.49929676511954996
# 	 Partición (75-25):   {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 9, 'splitter': 'random'}   0.49868766404199477
# 	 Partición (80-20):   {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 2, 'splitter': 'best'}   0.5086206896551724
